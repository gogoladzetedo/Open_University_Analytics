# %%
import pandas as pd
df = pd.read_csv("studentInfo.csv")
import matplotlib as plt
print(df["highest_education"].value_counts().plot(kind='bar'))
#print(df["age_band"].value_counts().plot(kind='bar'))
#print(df["age_band"].value_counts().plot(kind='bar'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
